# %%
import pandas as pd
import numpy as np
import requests
#To set the size of a dataframe in Python.
pd.set_option('display.max_rows', 800)
pd.set_option('display.max_columns', 800)

# %%
#Reference: https://www.google.com/covid19/mobility/
#Data comes from Kaggle https://www.kaggle.com/devinaconley/covid19-mobility-data
df = pd.read_csv(r'https://www.gstatic.com/covid19/mobility/Global_Mobility_Report.csv')
df
# Out:
# C:\Users\vw191\Downloads\annaconda\lib\site-packages\IPython\core\interactiveshell.py:3343: DtypeWarning: Columns (3,4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         country_region_code        country_region       sub_region_1  \
# 0                        AE  United Arab Emirates                NaN
# 1                        AE  United Arab Emirates                NaN
# 2                        AE  United Arab Emirates                NaN
# 3                        AE  United Arab Emirates                NaN
# 4                        AE  United Arab Emirates                NaN
# ...                     ...                   ...                ...
# 8365138                  ZW              Zimbabwe  Midlands Province
# 8365139                  ZW              Zimbabwe  Midlands Province
# 8365140                  ZW              Zimbabwe  Midlands Province
# 8365141                  ZW              Zimbabwe  Midlands Province
# 8365142                  ZW              Zimbabwe  Midlands Province
#
#         sub_region_2 metro_area iso_3166_2_code  census_fips_code  \
# 0                NaN        NaN             NaN               NaN
# 1                NaN        NaN             NaN               NaN
# 2                NaN        NaN             NaN               NaN
# 3                NaN        NaN             NaN               NaN
# 4                NaN        NaN             NaN               NaN
# ...              ...        ...             ...               ...
# 8365138       Kwekwe        NaN             NaN               NaN
# 8365139       Kwekwe        NaN             NaN               NaN
# 8365140       Kwekwe        NaN             NaN               NaN
# 8365141       Kwekwe        NaN             NaN               NaN
# 8365142       Kwekwe        NaN             NaN               NaN
#
#                             place_id        date  \
# 0        ChIJvRKrsd9IXj4RpwoIwFYv0zM  2020-02-15
# 1        ChIJvRKrsd9IXj4RpwoIwFYv0zM  2020-02-16
# 2        ChIJvRKrsd9IXj4RpwoIwFYv0zM  2020-02-17
# 3        ChIJvRKrsd9IXj4RpwoIwFYv0zM  2020-02-18
# 4        ChIJvRKrsd9IXj4RpwoIwFYv0zM  2020-02-19
# ...                              ...         ...
# 8365138  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2022-01-04
# 8365139  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2022-01-05
# 8365140  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2022-01-06
# 8365141  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2022-01-07
# 8365142  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2022-01-10
#
#          retail_and_recreation_percent_change_from_baseline  \
# 0                                                      0.0
# 1                                                      1.0
# 2                                                     -1.0
# 3                                                     -2.0
# 4                                                     -2.0
# ...                                                    ...
# 8365138                                                NaN
# 8365139                                                NaN
# 8365140                                                NaN
# 8365141                                                NaN
# 8365142                                                NaN
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                      4.0
# 1                                                      4.0
# 2                                                      1.0
# 3                                                      1.0
# 4                                                      0.0
# ...                                                    ...
# 8365138                                                NaN
# 8365139                                                NaN
# 8365140                                                NaN
# 8365141                                                NaN
# 8365142                                                NaN
#
#          parks_percent_change_from_baseline  \
# 0                                       5.0
# 1                                       4.0
# 2                                       5.0
# 3                                       5.0
# 4                                       4.0
# ...                                     ...
# 8365138                                 NaN
# 8365139                                 NaN
# 8365140                                 NaN
# 8365141                                 NaN
# 8365142                                 NaN
#
#          transit_stations_percent_change_from_baseline  \
# 0                                                  0.0
# 1                                                  1.0
# 2                                                  1.0
# 3                                                  0.0
# 4                                                 -1.0
# ...                                                ...
# 8365138                                            NaN
# 8365139                                            NaN
# 8365140                                            NaN
# 8365141                                            NaN
# 8365142                                            NaN
#
#          workplaces_percent_change_from_baseline  \
# 0                                            2.0
# 1                                            2.0
# 2                                            2.0
# 3                                            2.0
# 4                                            2.0
# ...                                          ...
# 8365138                                     33.0
# 8365139                                     34.0
# 8365140                                     36.0
# 8365141                                     38.0
# 8365142                                     33.0
#
#          residential_percent_change_from_baseline
# 0                                             1.0
# 1                                             1.0
# 2                                             1.0
# 3                                             1.0
# 4                                             1.0
# ...                                           ...
# 8365138                                       NaN
# 8365139                                       NaN
# 8365140                                       NaN
# 8365141                                       NaN
# 8365142                                       NaN
#
# [8365143 rows x 15 columns]

# %%
df['sub_region_1'][df['country_region']=='United Kingdom'].unique() #Checking to see the sub regions for the UK.
# Out:
# array([nan, 'Aberdeen City', 'Aberdeenshire', 'Angus Council',
#        'Antrim and Newtownabbey', 'Ards and North Down',
#        'Argyll and Bute Council', 'Armagh City, Banbridge and Craigavon',
#        'Bath and North East Somerset', 'Bedford', 'Belfast',
#        'Blackburn with Darwen', 'Blackpool', 'Blaenau Gwent',
#        'Borough of Halton', 'Bracknell Forest', 'Bridgend County Borough',
#        'Brighton and Hove', 'Bristol City', 'Buckinghamshire',
#        'Caerphilly County Borough', 'Cambridgeshire', 'Cardiff',
#        'Carmarthenshire', 'Causeway Coast and Glens',
#        'Central Bedfordshire', 'Ceredigion', 'Cheshire East',
#        'Cheshire West and Chester', 'Clackmannanshire',
#        'Conwy Principal Area', 'Cornwall', 'County Durham', 'Cumbria',
#        'Darlington', 'Denbighshire', 'Derby', 'Derbyshire',
#        'Derry and Strabane', 'Devon', 'Dorset', 'Dumfries and Galloway',
#        'Dundee City Council', 'East Ayrshire Council',
#        'East Dunbartonshire Council', 'East Lothian Council',
#        'East Renfrewshire Council', 'East Riding of Yorkshire',
#        'East Sussex', 'Edinburgh', 'Essex', 'Falkirk',
#        'Fermanagh and Omagh', 'Fife', 'Flintshire', 'Glasgow City',
#        'Gloucestershire', 'Greater London', 'Greater Manchester',
#        'Gwynedd', 'Hampshire', 'Hartlepool', 'Herefordshire',
#        'Hertfordshire', 'Highland Council', 'Inverclyde',
#        'Isle of Anglesey', 'Isle of Wight', 'Kent', 'Kingston upon Hull',
#        'Lancashire', 'Leicester', 'Leicestershire', 'Lincolnshire',
#        'Lisburn and Castlereagh', 'Luton', 'Medway', 'Merseyside',
#        'Merthyr Tydfil County Borough', 'Mid and East Antrim',
#        'Mid Ulster', 'Middlesbrough', 'Midlothian', 'Milton Keynes',
#        'Monmouthshire', 'Moray', 'Na h-Eileanan an Iar',
#        'Neath Port Talbot Principle Area', 'Newport',
#        'Newry, Mourne and Down', 'Norfolk', 'North Ayrshire Council',
#        'North East Lincolnshire', 'North Lanarkshire',
#        'North Lincolnshire', 'North Somerset', 'North Yorkshire',
#        'Northamptonshire', 'Northumberland', 'Nottingham',
#        'Nottinghamshire', 'Orkney', 'Oxfordshire', 'Pembrokeshire',
#        'Perth and Kinross', 'Peterborough', 'Plymouth', 'Portsmouth',
#        'Powys', 'Reading', 'Redcar and Cleveland', 'Renfrewshire',
#        'Rhondda Cynon Taff', 'Rutland', 'Scottish Borders',
#        'Shetland Islands', 'Shropshire', 'Slough', 'Somerset',
#        'South Ayrshire Council', 'South Gloucestershire',
#        'South Lanarkshire', 'South Yorkshire', 'Southampton',
#        'Southend-on-Sea', 'Staffordshire', 'Stirling', 'Stockton-on-Tees',
#        'Stoke-on-Trent', 'Suffolk', 'Surrey', 'Swansea', 'Swindon',
#        'Thurrock', 'Torbay', 'Torfaen Principal Area', 'Tyne and Wear',
#        'Vale of Glamorgan', 'Warrington', 'Warwickshire',
#        'West Berkshire', 'West Dunbartonshire Council', 'West Lothian',
#        'West Midlands', 'West Sussex', 'West Yorkshire', 'Wiltshire',
#        'Windsor and Maidenhead', 'Wokingham', 'Worcestershire',
#        'Wrexham Principal Area', 'York'], dtype=object)

# %%
dfuk = df[df['country_region']=='United Kingdom'] # Filtered for the UK

# %%
dfuk.columns.unique() #All column names are lower case with no spaces. THIS IS MY PREFERRED FORMAT :).
dfuk['sub_region_1'] = dfuk['sub_region_1'].fillna('UK')
dfuk['subreg1'] = dfuk['sub_region_1'].astype('str').str.replace(' ','_')
dfuk
dfuk.to_csv(r'C:\Users\vw191\OneDrive\Documents\GitHub\107SBakst.github.io\data\uk_google_mobility.csv')
# Out:
# <ipython-input-17-d7f1ee4c6ddd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfuk['sub_region_1'] = dfuk['sub_region_1'].fillna('UK')
# <ipython-input-17-d7f1ee4c6ddd>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfuk['subreg1'] = dfuk['sub_region_1'].astype('str').str.replace(' ','_')

# %%
dfuk['sub_region_2'] = dfuk['sub_region_2'].fillna('blank')
dfuk[(dfuk['subreg1']=='Greater_London') & (dfuk['sub_region_2'] == 'blank')].sort_values('date',ascending=False).head()
# Out:
# <ipython-input-59-c2ff7cdcb387>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfuk['sub_region_2'] = dfuk['sub_region_2'].fillna('blank')
#         country_region_code  country_region    sub_region_1 sub_region_2  \
# 3165311                  GB  United Kingdom  Greater London        blank
# 3165310                  GB  United Kingdom  Greater London        blank
# 3165309                  GB  United Kingdom  Greater London        blank
# 3165308                  GB  United Kingdom  Greater London        blank
# 3165307                  GB  United Kingdom  Greater London        blank
#
#         metro_area iso_3166_2_code  census_fips_code  \
# 3165311        NaN             NaN               NaN
# 3165310        NaN             NaN               NaN
# 3165309        NaN             NaN               NaN
# 3165308        NaN             NaN               NaN
# 3165307        NaN             NaN               NaN
#
#                             place_id        date  \
# 3165311  ChIJb-IaoQug2EcRi-m4hONz8S8  2022-01-11
# 3165310  ChIJb-IaoQug2EcRi-m4hONz8S8  2022-01-10
# 3165309  ChIJb-IaoQug2EcRi-m4hONz8S8  2022-01-09
# 3165308  ChIJb-IaoQug2EcRi-m4hONz8S8  2022-01-08
# 3165307  ChIJb-IaoQug2EcRi-m4hONz8S8  2022-01-07
#
#          retail_and_recreation_percent_change_from_baseline  \
# 3165311                                              -38.0
# 3165310                                              -34.0
# 3165309                                              -28.0
# 3165308                                              -41.0
# 3165307                                              -40.0
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 3165311                                              -12.0
# 3165310                                               -8.0
# 3165309                                              -13.0
# 3165308                                              -20.0
# 3165307                                              -11.0
#
#          parks_percent_change_from_baseline  \
# 3165311                               -24.0
# 3165310                               -10.0
# 3165309                                 6.0
# 3165308                               -52.0
# 3165307                               -27.0
#
#          transit_stations_percent_change_from_baseline  \
# 3165311                                          -49.0
# 3165310                                          -48.0
# 3165309                                          -38.0
# 3165308                                          -45.0
# 3165307                                          -51.0
#
#          workplaces_percent_change_from_baseline  \
# 3165311                                    -43.0
# 3165310                                    -43.0
# 3165309                                     -9.0
# 3165308                                    -15.0
# 3165307                                    -42.0
#
#          residential_percent_change_from_baseline         subreg1
# 3165311                                      15.0  Greater_London
# 3165310                                      15.0  Greater_London
# 3165309                                       5.0  Greater_London
# 3165308                                       9.0  Greater_London
# 3165307                                      16.0  Greater_London

# %%
import pandas as pd
import numpy as np
import requests

df = pd.read_csv(r'https://www.gstatic.com/covid19/mobility/Global_Mobility_Report.csv')
df

dfuk = df[df['country_region']=='United Kingdom'] # Filtered for the UK
dfuk['sub_region_1'] = dfuk['sub_region_1'].fillna('UK')
dfuk['subreg1'] = dfuk['sub_region_1'].astype('str').str.replace(' ','_')
dfuk
csv_final = dfuk.to_csv('uk_google_mobility.csv')

import base64
from github import Github
from pprint import pprint



username = "107SBakst"
password = "gjr9e2bphjv2zwk"

# authenticate to github
g = Github(username, password)
# get the authenticated user
user = g.get_user(username)
for repo in user.get_repos():
    print(repo)


repo = g.get_repo("107SBakst/107SBakst.github.io")
contents = repo.get_contents(csv_final)
repo.update_file(contents.path, "more data", "more data", contents.sha, branch="main")

#contents = repo.get_contents(git_file)
#repo.update_file(contents.path, "committing files", content, contents.sha, branch="main")
#print(git_file + ' UPDATED')
# Out:
# C:\Users\vw191\Downloads\annaconda\lib\site-packages\IPython\core\interactiveshell.py:3343: DtypeWarning: Columns (3,4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# <ipython-input-60-32866d2fd14b>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfuk['sub_region_1'] = dfuk['sub_region_1'].fillna('UK')
# <ipython-input-60-32866d2fd14b>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfuk['subreg1'] = dfuk['sub_region_1'].astype('str').str.replace(' ','_')
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-60-32866d2fd14b> in <module>
#      10 dfuk['subreg1'] = dfuk['sub_region_1'].astype('str').str.replace(' ','_')
#      11 dfuk
# ---> 12 csv_final = dfuk.to_csv('data/uk_google_mobility.csv')
#      13
#      14 import base64
#
# ~\Downloads\annaconda\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3464         )
#    3465
# -> 3466         return DataFrameRenderer(formatter).to_csv(
#    3467             path_or_buf,
#    3468             line_terminator=line_terminator,
#
# ~\Downloads\annaconda\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# ~\Downloads\annaconda\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     235         """
#     236         # apply compression and byte/text conversion
# --> 237         with get_handle(
#     238             self.filepath_or_buffer,
#     239             self.mode,
#
# ~\Downloads\annaconda\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/uk_google_mobility.csv'

# %%
csv_final = dfuk.to_csv('uk_google_mobility.csv')

import base64
from github import Github
from pprint import pprint



username = "107SBakst"
password = "gjr9e2bphjv2zwk"

# authenticate to github
g = Github(username, password)
# get the authenticated user
user = g.get_user(username)
for repo in user.get_repos():
    print(repo)


repo = g.get_repo("107SBakst/107SBakst.github.io")
contents = repo.get_contents("data/"+"uk_google_mobility.csv")
repo.update_file(contents.path, "more data", "more data", contents.sha, branch="main")

#contents = repo.get_contents(git_file)
#repo.update_file(contents.path, "committing files", content, contents.sha, branch="main")
#print(git_file + ' UPDATED')
# Out:
# Repository(full_name="107SBakst/107SBakst.github.io")
# Repository(full_name="107SBakst/RDeconomist.github.io")
# Repository(full_name="107SBakst/sbakst.github.io")
# ---------------------------------------------------------------------------
# GithubException                           Traceback (most recent call last)
# <ipython-input-65-a43535e2858d> in <module>
#      19
#      20 repo = g.get_repo("107SBakst/107SBakst.github.io")
# ---> 21 contents = repo.get_contents("data/"+"uk_google_mobility.csv")
#      22 repo.update_file(contents.path, "more data", "more data", contents.sha, branch="main")
#      23
#
# ~\Downloads\annaconda\lib\site-packages\github\Repository.py in get_contents(self, path, ref)
#    1787         if ref is not github.GithubObject.NotSet:
#    1788             url_parameters["ref"] = ref
# -> 1789         headers, data = self._requester.requestJsonAndCheck(
#    1790             "GET",
#    1791             f"{self.url}/contents/{urllib.parse.quote(path)}",
#
# ~\Downloads\annaconda\lib\site-packages\github\Requester.py in requestJsonAndCheck(self, verb, url, parameters, headers, input)
#     351
#     352     def requestJsonAndCheck(self, verb, url, parameters=None, headers=None, input=None):
# --> 353         return self.__check(
#     354             *self.requestJson(
#     355                 verb, url, parameters, headers, input, self.__customConnection(url)
#
# ~\Downloads\annaconda\lib\site-packages\github\Requester.py in __check(self, status, responseHeaders, output)
#     376         output = self.__structuredFromJson(output)
#     377         if status >= 400:
# --> 378             raise self.__createException(status, responseHeaders, output)
#     379         return responseHeaders, output
#     380
#
# GithubException: 403 {"message": "This API returns blobs up to 1 MB in size. The requested blob is too large to fetch via the API, but you can use the Git Data API to request blobs up to 100 MB in size.", "errors": [{"resource": "Blob", "field": "data", "code": "too_large"}], "documentation_url": "https://docs.github.com/rest/reference/repos#get-repository-content"}
