# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/covid19-mobility-data/Global_Mobility_Report.csv

# %%
df = pd.read_csv(os.path.join(dirname, filename))
dfuk = df[df['country_region']=='United Kingdom'] # Filtered for the UK
dfuk['sub_region_1'] = dfuk['sub_region_1'].fillna('UK')
dfuk['subreg1'] = dfuk['sub_region_1'].astype('str').str.replace(' ','_')
dfuk.head()
# Out:
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (3,4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#         country_region_code  country_region sub_region_1 sub_region_2  \
# 3058089                  GB  United Kingdom           UK          NaN
# 3058090                  GB  United Kingdom           UK          NaN
# 3058091                  GB  United Kingdom           UK          NaN
# 3058092                  GB  United Kingdom           UK          NaN
# 3058093                  GB  United Kingdom           UK          NaN
#
#         metro_area iso_3166_2_code  census_fips_code  \
# 3058089        NaN             NaN               NaN
# 3058090        NaN             NaN               NaN
# 3058091        NaN             NaN               NaN
# 3058092        NaN             NaN               NaN
# 3058093        NaN             NaN               NaN
#
#                             place_id        date  \
# 3058089  ChIJqZHHQhE7WgIReiWIMkOg-MQ  2020-02-15
# 3058090  ChIJqZHHQhE7WgIReiWIMkOg-MQ  2020-02-16
# 3058091  ChIJqZHHQhE7WgIReiWIMkOg-MQ  2020-02-17
# 3058092  ChIJqZHHQhE7WgIReiWIMkOg-MQ  2020-02-18
# 3058093  ChIJqZHHQhE7WgIReiWIMkOg-MQ  2020-02-19
#
#          retail_and_recreation_percent_change_from_baseline  \
# 3058089                                              -12.0
# 3058090                                               -7.0
# 3058091                                               10.0
# 3058092                                                7.0
# 3058093                                                6.0
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 3058089                                               -7.0
# 3058090                                               -6.0
# 3058091                                                1.0
# 3058092                                               -1.0
# 3058093                                               -2.0
#
#          parks_percent_change_from_baseline  \
# 3058089                               -35.0
# 3058090                               -28.0
# 3058091                                24.0
# 3058092                                20.0
# 3058093                                 8.0
#
#          transit_stations_percent_change_from_baseline  \
# 3058089                                          -12.0
# 3058090                                           -7.0
# 3058091                                           -2.0
# 3058092                                           -3.0
# 3058093                                           -4.0
#
#          workplaces_percent_change_from_baseline  \
# 3058089                                     -4.0
# 3058090                                     -3.0
# 3058091                                    -14.0
# 3058092                                    -14.0
# 3058093                                    -14.0
#
#          residential_percent_change_from_baseline subreg1
# 3058089                                       2.0      UK
# 3058090                                       1.0      UK
# 3058091                                       2.0      UK
# 3058092                                       2.0      UK
# 3058093                                       3.0      UK
