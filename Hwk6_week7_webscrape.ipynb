# %% [markdown]
# <a href="https://colab.research.google.com/github/107SBakst/107SBakst.github.io/blob/main/Hwk6_week7_webscrape.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests, pandas as pd

# %%
from bs4 import BeautifulSoup

# %%
url='https://en.wikipedia.org/wiki/List_of_Academy_Award-winning_films'

# %%
tables=pd.read_html('https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table')
tables
# Out:
# [                                       Olympic Games
#  0                                        Main topics
#  1  Bids Boycotts Ceremonies Charter Host cities I...
#  2                                              Games
#  3  Summer Winter Youth African Asian European Pac...
#  4  .mw-parser-output .navbar{display:inline;font-...,
#                                               Team  ... Combined total
#                                    Team (IOC code)  ...          Total
#  0                               Afghanistan (AFG)  ...              2
#  1                                   Algeria (ALG)  ...             17
#  2                                 Argentina (ARG)  ...             77
#  3                                   Armenia (ARM)  ...             18
#  4                         Australasia (ANZ) [ANZ]  ...             12
#  ..                                            ...  ...            ...
#  152                          Zimbabwe (ZIM) [ZIM]  ...              8
# ...

# %%
df=tables[1]
df.columns=['Team (IOC Code)', 'Summer_rank_medals', 'Summer_Gold', 'Summer_silver', 'Summer_bronze', 'Summer_total', 'Winter_rank_medals', 'Winter_Gold', 'Winter_silver', 'Winter_bronze', 'Winter_total', 'Combined_rank_medals', 'Combined_Gold', 'Combined_silver', 'Combined_bronze', 'Combined_total']
type(df)
df
# Out:
#                                   Team (IOC Code)  ...  Combined_total
# 0                               Afghanistan (AFG)  ...               2
# 1                                   Algeria (ALG)  ...              17
# 2                                 Argentina (ARG)  ...              77
# 3                                   Armenia (ARM)  ...              18
# 4                         Australasia (ANZ) [ANZ]  ...              12
# ..                                            ...  ...             ...
# 152                          Zimbabwe (ZIM) [ZIM]  ...               8
# 153      Independent Olympic Athletes (IOA) [IOA]  ...               2
# 154  Independent Olympic Participants (IOP) [IOP]  ...               3
# 155                        Mixed team (ZZX) [ZZX]  ...              16
# 156                                        Totals  ...           18876
#
# [157 rows x 16 columns]

# %%
df.drop([156])
# Out:
#                                   Team (IOC Code)  ...  Combined_total
# 0                               Afghanistan (AFG)  ...               2
# 1                                   Algeria (ALG)  ...              17
# 2                                 Argentina (ARG)  ...              77
# 3                                   Armenia (ARM)  ...              18
# 4                         Australasia (ANZ) [ANZ]  ...              12
# ..                                            ...  ...             ...
# 151                            Zambia (ZAM) [ZAM]  ...               2
# 152                          Zimbabwe (ZIM) [ZIM]  ...               8
# 153      Independent Olympic Athletes (IOA) [IOA]  ...               2
# 154  Independent Olympic Participants (IOP) [IOP]  ...               3
# 155                        Mixed team (ZZX) [ZZX]  ...              16
#
# [156 rows x 16 columns]

# %%
df.to_csv('Olympic.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-444314313f73> in <module>()
# ----> 1 df.to_csv('Olympic.csv')
#
# NameError: name 'df' is not defined
